# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("/content/Cardiotocographic.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [markdown]
# # Data Cleaning and Preparation

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ### Checking for Null values

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data[data["LB"].isnull()]  #21 null values are found for the 2126 rows.21 is smaller number compares to 2126 so null values are removing.
# Out:
#       LB        AC        FM        UC        DL  DS  DP       ASTV      MSTV  \
# 50   NaN       NaN  0.000000  0.008086  0.000000 NaN NaN  29.000000  1.300000
# 116  NaN  0.038567  0.000000  0.006993  0.002331 NaN NaN  26.000000  4.300000
# 126  NaN       NaN  0.000000  0.004380  0.000000 NaN NaN  69.000000  0.300000
# 201  NaN       NaN  0.016393  0.000000  0.000000 NaN NaN  56.000000  0.500000
# 566  NaN       NaN  0.000000  0.004115  0.005487 NaN NaN  43.000000  2.500000
# 574  NaN       NaN  0.000000  0.002611  0.002611 NaN NaN  34.000000  4.900000
# 603  NaN       NaN  0.006519  0.001304  0.001304 NaN NaN  73.000000  0.700000
# 935  NaN       NaN  0.000000  0.005495  0.001374 NaN NaN  30.000000  1.251793
# 936  NaN       NaN  0.000000  0.007802  0.000000 NaN NaN  33.000000  1.000000
# 1013 NaN       NaN  0.000000  0.003861  0.000000 NaN NaN  34.000000  1.000000
# 1205 NaN       NaN -0.000129  0.006424  0.000000 NaN NaN  63.000000  0.500000
# ...

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (2105, 14)

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
data.reset_index(inplace=True)

# %%
data.drop("index",axis=1,inplace=True)

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2100  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2101  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2102  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2103  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2104  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ###Checking for Duplicates

# %%
data[data.duplicated(keep=False)]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1103  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1105  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1443  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
# 1444  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1103   39.0       0.0  1.0
# 1105   39.0       0.0  1.0
# 1443   35.0       0.0  1.0
# 1444   35.0       0.0  1.0

# %%
data[data.duplicated(keep="first")]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1105  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1444  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1105   39.0       0.0  1.0
# 1444   35.0       0.0  1.0

# %%
data.drop_duplicates(keep="first",inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2103 entries, 0 to 2104
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2103 non-null   float64
#  1   AC        2103 non-null   float64
#  2   FM        2103 non-null   float64
#  3   UC        2103 non-null   float64
#  4   DL        2103 non-null   float64
#  5   DS        2103 non-null   float64
#  6   DP        2103 non-null   float64
#  7   ASTV      2103 non-null   float64
#  8   MSTV      2103 non-null   float64
#  9   ALTV      2103 non-null   float64
#  10  MLTV      2103 non-null   float64
#  11  Width     2103 non-null   float64
#  12  Tendency  2103 non-null   float64
#  13  NSP       2103 non-null   float64
# dtypes: float64(14)
# memory usage: 246.4 KB

# %%
data[data.duplicated(keep=False)].sum().sum()
# Out:
# 0.0

# %% [markdown]
# ###Applying Standardisation

# %%
def standardize(x):
  standard_data= (x-x.mean())/x.std()
  return standard_data

# %%
standard_data=standardize(data)

# %% [markdown]
# ## Detecting and Treating Outliers

# %%
z_score_LB=standard_data["LB"]

# %%
plt.boxplot(standard_data["LB"])
plt.show()

# %%
z_score_LB[z_score_LB>2]=z_score_LB.mean()
z_score_LB[z_score_LB<-2]=z_score_LB.mean()

# %%
plt.boxplot(z_score_LB)
plt.show()

# %%
z_score_AC=standard_data["AC"]

# %%
plt.boxplot(z_score_AC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef581827550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef581827a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5818272b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef581827fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef58185c2b0>],
#  'means': []}

# %%
z_score_AC[z_score_AC>2.2]=z_score_AC.mean()

# %%
z_score_AC[z_score_AC<-2]=z_score_AC.mean()

# %%
plt.boxplot(z_score_AC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef5816a2dd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef5816a3310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5816a2b30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef5816a3850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef5816a3af0>],
#  'means': []}

# %%
z_score_FM=standard_data["FM"]

# %%
plt.boxplot(z_score_FM)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef581719e70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef58171a3b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef581719bd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef58171a8f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef58171ab90>],
#  'means': []}

# %%
z_score_FM[z_score_FM>2]=z_score_FM.mean()
z_score_FM[z_score_FM<-5]=z_score_FM.mean()

# %%
plt.boxplot(z_score_FM)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef581773fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef5815b0520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef581773d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef5815b0a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef5815b0d00>],
#  'means': []}

# %%
z_score_UC=standard_data["UC"]

# %%
plt.boxplot(z_score_UC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef5815fa7d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef5815fabf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5815fa530>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef5815fb130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef5815fb3d0>],
#  'means': []}

# %%
z_score_UC[z_score_UC>2.8]=z_score_UC.mean()
z_score_UC[z_score_UC<-2]=z_score_UC.mean()

# %%
plt.boxplot(z_score_UC)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef58166e8c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef58166ebc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef58166e620>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef58166f130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef58166f3d0>],
#  'means': []}

# %%
z_score_DL=standard_data["DL"]

# %%
plt.boxplot(z_score_DL)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef5814eb6a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef5814ebbe0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5814ea470>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef581520160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef581520400>],
#  'means': []}

# %%
z_score_DL[z_score_DL>2]=z_score_DL.mean()
z_score_DL[z_score_DL<-2]=z_score_DL.mean()

# %%
plt.boxplot(z_score_DL)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef58156aaa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef58156afe0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef581568e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef58156b520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef58156b7c0>],
#  'means': []}

# %%
z_score_DS=standard_data["DS"]

# %%
plt.boxplot(z_score_DS)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57f1f1c00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57f1f2140>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57f1f1960>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57f1f2680>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57f1f2920>],
#  'means': []}

# %%
z_score_DS[z_score_DS>2]=z_score_DS.mean()
z_score_DS[z_score_DS<-2]=z_score_DS.mean()

# %%
plt.boxplot(z_score_DS)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57f265060>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57f2655a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57f264dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57f265ae0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57f265d80>],
#  'means': []}

# %%
z_score_DP=standard_data["DP"]

# %%
z_score_DP[z_score_DP>2.5]=z_score_DP.mean()
z_score_DP[z_score_DP<-2.5]=z_score_DP.mean()

# %%
plt.boxplot(z_score_DP)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57f0bb7c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57f0bbd00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57f0bb640>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57f0f4280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57f0f4520>],
#  'means': []}

# %%
z_score_ASTV=standard_data["ASTV"]

# %%
plt.boxplot(z_score_ASTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57f13e890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57f13ecb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57f13e5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57f13f1f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57f13f490>],
#  'means': []}

# %%
z_score_ASTV[z_score_ASTV>3]=z_score_ASTV.mean()
z_score_ASTV[z_score_ASTV<-3]=z_score_ASTV.mean()

# %%
plt.boxplot(z_score_ASTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57efb5f90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57efb63b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57efb5cf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57efb68f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57efb6b90>],
#  'means': []}

# %%
z_score_MSTV=standard_data["MSTV"]

# %%
plt.boxplot(z_score_MSTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57f02a8c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57f02ae00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57f02a650>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57f02b340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57f02b5e0>],
#  'means': []}

# %%
z_score_MSTV[z_score_MSTV>2.5].count()
# Out:
# 30

# %%
z_score_MSTV[z_score_MSTV>1.5]=z_score_MSTV.mean()
z_score_MSTV[z_score_MSTV<-2]=z_score_MSTV.mean()

# %%
plt.boxplot(z_score_MSTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57eeb2e00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57eeb3340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57eeb2c80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57eeb3880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57eeb3b20>],
#  'means': []}

# %%
z_score_ALTV=standard_data["ALTV"]

# %%
plt.boxplot(z_score_ALTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57ef29b40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57ef29f60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57ef298a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57ef2a4a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57ef2a740>],
#  'means': []}

# %%
z_score_ALTV[z_score_ALTV>0.3]=z_score_ALTV.mean()
z_score_ALTV[z_score_ALTV<-2]=z_score_ALTV.mean()

# %%
plt.boxplot(z_score_ALTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57edad480>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57edad8a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57edad1e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57edadde0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57edae080>],
#  'means': []}

# %%
z_score_MLTV=standard_data["MLTV"]

# %%
plt.boxplot(z_score_MLTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef5815b22c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef5815fb910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5815b17b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef581628130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef5816291e0>],
#  'means': []}

# %%
z_score_MLTV[z_score_MLTV>1.5]=z_score_MLTV.mean()
z_score_MLTV[z_score_MLTV<-2]=z_score_MLTV.mean()

# %%
plt.boxplot(z_score_MLTV)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57edd4820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57edd5db0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57edd4670>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57ef044f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef5818040a0>],
#  'means': []}

# %%
z_score_Width=standard_data["Width"]

# %%
plt.boxplot(z_score_Width)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef5812cc760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef58191ed70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5812cceb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef58191f970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef58191fa60>],
#  'means': []}

# %%
z_score_Width[z_score_Width>4]=z_score_Width.mean()
z_score_Width[z_score_Width<-2]=z_score_Width.mean()

# %%
plt.boxplot(z_score_Width)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef5818c8970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef58134fc10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef5818cb880>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef58134d510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef58134c190>],
#  'means': []}

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2100  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2101  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2102  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2103  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2104  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
z_score_Tendency=standard_data["Tendency"]

# %%
plt.boxplot(z_score_Tendency)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57ecd3c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57ecf4190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57ecd3970>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57ecf46d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57ecf4970>],
#  'means': []}

# %%
z_score_Tendency[z_score_Tendency>2]=z_score_Tendency.mean()
z_score_Tendency[z_score_Tendency<-4]=z_score_Tendency.mean()

# %%
plt.boxplot(z_score_Tendency)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57ed423b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57ed427d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57ed42110>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57ed42d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57ed42fb0>],
#  'means': []}

# %%
z_score_NSP=standard_data["NSP"]

# %%
plt.boxplot(z_score_NSP)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57ebc9750>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57ebc9c90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57ebc94b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57ebca1d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57ebca470>],
#  'means': []}

# %%
z_score_NSP[z_score_NSP>4]=z_score_NSP.mean()
z_score_NSP[z_score_NSP<-2]=z_score_NSP.mean()

# %%
plt.boxplot(z_score_NSP)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef57ec44970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef57ec44eb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef57ec446d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef57ec453f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef57ec45690>],
#  'means': []}

# %%
standard_data.drop(standard_data.columns[:],axis=1,inplace=True)

# %%
standard_data["LB"]=z_score_LB
standard_data["AC"]=z_score_AC
standard_data["FM"]=z_score_FM
standard_data["UC"]=z_score_UC
standard_data["DL"]=z_score_DL
standard_data["DS"]=z_score_DS
standard_data["DP"]=z_score_DP
standard_data["ASTV"]=z_score_ASTV
standard_data["MSTV"]=z_score_MSTV
standard_data["ALTV"]=z_score_ALTV
standard_data["MLTV"]=z_score_MLTV
standard_data["Width"]=z_score_Width
standard_data["Tendency"]=z_score_Tendency
standard_data["NSP"]=z_score_NSP

# %%
standard_data
# Out:
#             LB        AC        FM        UC        DL        DS        DP  \
# 0    -1.184035 -0.740574 -0.146872 -1.310782 -0.565520 -0.017735 -0.208674
# 1    -0.119098  0.734472 -0.146872  0.593799  0.386881 -0.017735 -0.208674
# 2    -0.030353  0.027577 -0.146872  1.168812  0.426432 -0.017735 -0.208674
# 3     0.058392 -0.148478 -0.146872  1.000503  0.199083 -0.017735 -0.208674
# 4    -0.123692  0.765702 -0.146872  1.120351 -0.565520 -0.017735 -0.208674
# ...        ...       ...       ...       ...       ...       ...       ...
# 2100  0.590861 -0.740574  0.000000  0.906123 -0.565520 -0.017735 -0.208674
# 2101  0.590861 -0.561477 -0.146872  0.772823 -0.565520 -0.017735 -0.208674
# 2102  0.590861 -0.513894 -0.146872  0.738043 -0.565520 -0.017735 -0.208674
# 2103  0.590861 -0.583606 -0.146872  0.513311 -0.565520 -0.017735 -0.208674
# 2104  0.768350 -0.367046 -0.149634  1.100713 -0.565520 -0.017735 -0.208674
#
# ...

# %% [markdown]
# # Statistical Summary

# %%
standard_data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2103.000000
# mean     -0.007809    -0.077865    -0.084416    -0.015058    -0.118538
# std       0.792643     0.774291     0.184727     0.870824     0.670256
# min      -1.893994    -0.783317    -0.222062    -1.350058    -0.602502
# 25%      -0.562822    -0.740574    -0.146872    -0.754317    -0.565520
# 50%      -0.030353    -0.357135    -0.146872     0.019032    -0.565520
# 75%       0.590861     0.416457    -0.108619     0.632015     0.133575
# max       1.833288     2.198580     1.904367     2.566401     1.982071
#
#                 DS           DP         ASTV         MSTV          ALTV  \
# count  2103.000000  2103.000000  2103.000000  2103.000000  2.103000e+03
# mean     -0.017614    -0.098759    -0.000662    -0.113438 -3.174896e-01
# std       0.004818     0.430203     0.911260     0.568890  2.281083e-01
# ...

# %% [markdown]
# ### Interpretation

# %% [markdown]
# After treating the outliers,the mean and mode value for all columns came near to same value which it shows the distribution is normal.
# It is found that the maximum value found among the all columns was 2.68 for the NSP column and minimum value was -0.22 for the fetal movements column

# %% [markdown]
# # Visualization

# %%
fig=plt.figure(figsize=(15,25))
plt.subplot(5,3,1)
plt.boxplot(standard_data["LB"])
plt.title("Baseline Fetal Heart Rate")
plt.subplot(5,3,2)
plt.boxplot(standard_data["AC"])
plt.title("Accelerations")
plt.subplot(5,3,3)
plt.boxplot(standard_data["FM"])
plt.title("Fetal movements")
plt.subplot(5,3,4)
plt.boxplot(standard_data["UC"])
plt.title("Uterine Contractions")
plt.subplot(5,3,5)
plt.boxplot(standard_data["DL"])
plt.title("Decelerations Late")
plt.subplot(5,3,6)
plt.boxplot(standard_data["DS"])
plt.title("Decelerations Short")
plt.subplot(5,3,7)
plt.boxplot(standard_data["DP"])
plt.title("Decelerations Prolonged")
plt.subplot(5,3,8)
plt.boxplot(standard_data["ASTV"])
plt.title("Percentage of Time with Abnormal Short Term Variability")
plt.subplot(5,3,9)
plt.boxplot(standard_data["Width"])
plt.title("Width")
plt.subplot(5,3,10)
plt.boxplot(standard_data["ALTV"])
plt.title("Percentage of Time with Abnormal Long Term Variability")
plt.subplot(5,3,11)
plt.boxplot(standard_data["MLTV"])
plt.title("Mean Value of Long Term Variability")
plt.subplot(5,3,12)
plt.boxplot(standard_data["MSTV"])
plt.title("Percentage of Time with Abnormal Short Term Variability")
plt.subplot(5,3,13)
plt.boxplot(standard_data["Tendency"])
plt.title("Tendency")
plt.subplot(5,3,14)
plt.boxplot(standard_data["NSP"])
plt.title("NSP")

plt.show()

# %%
fig=plt.figure(figsize=(15,25))
plt.subplot(5,3,1)
plt.hist(standard_data["LB"])
plt.title("Baseline Fetal Heart Rate")
plt.subplot(5,3,2)
plt.hist(standard_data["AC"])
plt.title("Accelerations")
plt.subplot(5,3,3)
plt.hist(standard_data["FM"])
plt.title("Fetal movements")
plt.subplot(5,3,4)
plt.hist(standard_data["UC"])
plt.title("Uterine Contractions")
plt.subplot(5,3,5)
plt.hist(standard_data["DL"])
plt.title("Decelerations Late")
plt.subplot(5,3,6)
plt.hist(standard_data["DS"])
plt.title("Decelerations Short")
plt.subplot(5,3,7)
plt.hist(standard_data["DP"])
plt.title("Decelerations Prolonged")
plt.subplot(5,3,8)
plt.hist(standard_data["ASTV"])
plt.title("Percentage of Time with Abnormal Short Term Variability")
plt.subplot(5,3,9)
plt.hist(standard_data["Width"])
plt.title("Width")
plt.subplot(5,3,10)
plt.hist(standard_data["ALTV"])
plt.title("Percentage of Time with Abnormal Long Term Variability")
plt.subplot(5,3,11)
plt.hist(standard_data["MLTV"])
plt.title("Mean Value of Long Term Variability")
plt.subplot(5,3,12)
plt.hist(standard_data["MSTV"])
plt.title("Percentage of Time with Abnormal Short Term Variability")
plt.subplot(5,3,13)
plt.hist(standard_data["Tendency"])
plt.title("Tendency")
plt.subplot(5,3,14)
plt.hist(standard_data["NSP"])
plt.title("NSP")

plt.show()

# %%
fig=plt.figure(figsize=(20,20))
plt.subplot(2,3,1)
plt.scatter(standard_data["LB"],standard_data["AC"])
plt.xlabel("Baseline Fetal Heart Rate")
plt.ylabel("Accelerations")
plt.title("Baseline Fetal Heart Rate vs Accelerations")
plt.subplot(2,3,2)
plt.scatter(standard_data["FM"],standard_data["UC"])
plt.xlabel("Fetal Movements")
plt.ylabel("Uterine Contractions")
plt.title("Fetal Movements vs Uterine contractions")
plt.subplot(2,3,3)
plt.scatter(standard_data["DL"],standard_data["DS"])
plt.xlabel("Decelerations Late")
plt.ylabel("Decelerations short")
plt.title("Decelerations Late vs Decelerations short")
plt.subplot(2,3,4)
plt.scatter(standard_data["ASTV"],standard_data["MSTV"])
plt.xlabel("Percentage of Time with Abnormal Short Term Variability")
plt.ylabel("Mean Value of Short Term Variability")
plt.title("Percentage of Time with Abnormal Short Term Variability vs Mean Value of Short Term Variability")
plt.subplot(2,3,6)
plt.scatter(standard_data["ALTV"],standard_data["MLTV"])
plt.xlabel("Percentage of Time with Abnormal Long Term Variability")
plt.ylabel("Mean Value of Long Term Variability")
plt.title("Percentage of Time with Abnormal Long Term Variability vs Mean Value of Long Term Variability")
# Out:
# Text(0.5, 1.0, 'Percentage of Time with Abnormal Long Term Variability vs Mean Value of Long Term Variability')

# %%
fig=plt.figure(figsize=(20,50))
sns.pairplot(standard_data)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7ef5c5060f70> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#     121
#     122
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for manager in cls.get_all_fig_managers():
#     131             if force or manager.canvas.figure.stale:
# --> 132                 manager.canvas.draw_idle()
#     133
#     134
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2080         if not self._is_idle_drawing:
#    2081             with self._idle_draw_cntx():
# ...

# %%
standard_data.corr()
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.121290 -0.047611 -0.134653 -0.109444  0.017930
# AC       -0.121290  1.000000  0.105521  0.121879 -0.041138  0.006450
# FM       -0.047611  0.105521  1.000000 -0.190751 -0.004488 -0.005727
# UC       -0.134653  0.121879 -0.190751  1.000000  0.267275  0.027690
# DL       -0.109444 -0.041138 -0.004488  0.267275  1.000000  0.017211
# DS        0.017930  0.006450 -0.005727  0.027690  0.017211  1.000000
# DP       -0.120965 -0.106783 -0.000199  0.174768  0.307630  0.041838
# ASTV      0.358838 -0.273745 -0.039164 -0.231474 -0.153350  0.022540
# MSTV     -0.316497  0.228013  0.101417  0.324458  0.496822  0.022814
# ALTV      0.318541 -0.433129 -0.114358 -0.269235 -0.295095 -0.033704
# MLTV     -0.082499 -0.110516  0.000065 -0.090475 -0.198420 -0.027958
# Width    -0.120020  0.279706  0.214143  0.138455  0.511052  0.028220
# Tendency  0.258460 -0.008800  0.033315 -0.077735  0.086909 -0.011726
# ...

# %% [markdown]
# ### Finding correlation through Heatmap

# %%
plt.figure(figsize=(15,15))
sns.heatmap(standard_data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Pattern Recognition and Insights

# %% [markdown]
# *   The column "width" and "Percentage of Time with Abnormal Short Term Variability" following Negative correlation.
# *   The column "width" and "Mean Value of Short Term Variability" following Positive correlation.
# *   The column "width" and "Decelerations Late" are positively correlated.
#
# *   The column "Accelerations" and "Percentage of Time with Abnormal Short Term Variability" following Positive correlation.
# *   The column "Mean Value of Short Term Variability" and "Decelerations Late" are positively correlated.
#
# *   The column "Mean Value of Short Term Variability" and "Percentage of Time with Abnormal Short Term Variability" are Negatively correlated.
# *   The column "Mean Value of Short Term Variability" and "Percentage of Time with Abnormal Long Term Variability" are Negatively correlated.
#
# These above columns are Moderately correlated.There are many columns which I didnt mentioned here having weak relation.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Data Quality :-

# %% [markdown]
# After detecting and treated the missing values and outliers,it makes the good data which can be used for any model and we can easily get good model accuracy.

# %% [markdown]
# ### Correlations:-

# %% [markdown]
# As per the scatter and pair plots,it is identified most of columns are following very weak correlation(positive and negative).Only very some columns are following moderate correlation.

# %% [markdown]
# ### Distribution:-

# %% [markdown]
# Only the column "Baseline Fetal heart rate" following Normal distribution and all other columns mostly positively/negatively skewed distributions.

# %% [markdown]
# By these assignment,we can understood EDA helps uncover hidden patterns,relationships and anamolies in the data.
